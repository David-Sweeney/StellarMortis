# %% [markdown]
# # Upload to Zenodo

# %%
import requests

# %%
ACCESS_TOKEN = 'fpp9p2HooDERwqSx3RvBFAs6NkZVPVIIKSQr0bpDuHyP0WMglBvPLB96bJ3K'
r = requests.get('https://zenodo.org/api/deposit/depositions',
                  params={'access_token': ACCESS_TOKEN})
print(r.status_code)
print(r.json())
# Out:
# 200
# [{'created': '2024-11-08T04:22:32.914985+00:00', 'modified': '2024-11-08T05:18:13.455233+00:00', 'id': 14053534, 'conceptrecid': '14053533', 'doi': '', 'doi_url': 'https://doi.org/', 'metadata': {'doi': '', 'publication_date': '2024-11-08', 'access_right': 'open', 'license': 'cc-by-4.0', 'imprint_publisher': 'Zenodo', 'prereserve_doi': {'doi': '10.5281/zenodo.14053534', 'recid': 14053534}}, 'title': '', 'links': {'self': 'https://zenodo.org/api/deposit/depositions/14053534', 'html': 'https://zenodo.org/deposit/14053534', 'doi': 'https://doi.org/', 'badge': 'https://zenodo.org/badge/doi/.svg', 'files': 'https://zenodo.org/api/deposit/depositions/14053534/files', 'latest_draft': 'https://zenodo.org/api/deposit/depositions/14053534', 'latest_draft_html': 'https://zenodo.org/deposit/14053534', 'publish': 'https://zenodo.org/api/deposit/depositions/14053534/actions/publish', 'edit': 'https://zenodo.org/api/deposit/depositions/14053534/actions/edit', 'discard': 'https://zenodo.org/api/deposit/depositions/14053534/actions/discard', 'newversion': 'https://zenodo.org/api/deposit/depositions/14053534/actions/newversion', 'registerconceptdoi': 'https://zenodo.org/api/deposit/depositions/14053534/actions/registerconceptdoi'}, 'record_id': 14053534, 'owner': 393191, 'files': [], 'state': 'unsubmitted', 'submitted': False}, {'created': '2024-11-07T02:46:23.701388+00:00', 'modified': '2024-11-07T02:46:23.784475+00:00', 'id': 14048336, 'conceptrecid': '14048335', 'doi': '', 'doi_url': 'https://doi.org/', 'metadata': {'doi': '', 'publication_date': '2024-11-07', 'access_right': 'open', 'license': 'cc-by-4.0', 'imprint_publisher': 'Zenodo', 'prereserve_doi': {'doi': '10.5281/zenodo.14048336', 'recid': 14048336}}, 'title': '', 'links': {'self': 'https://zenodo.org/api/deposit/depositions/14048336', 'html': 'https://zenodo.org/deposit/14048336', 'doi': 'https://doi.org/', 'badge': 'https://zenodo.org/badge/doi/.svg', 'files': 'https://zenodo.org/api/deposit/depositions/14048336/files', 'latest_draft': 'https://zenodo.org/api/deposit/depositions/14048336', 'latest_draft_html': 'https://zenodo.org/deposit/14048336', 'publish': 'https://zenodo.org/api/deposit/depositions/14048336/actions/publish', 'edit': 'https://zenodo.org/api/deposit/depositions/14048336/actions/edit', 'discard': 'https://zenodo.org/api/deposit/depositions/14048336/actions/discard', 'newversion': 'https://zenodo.org/api/deposit/depositions/14048336/actions/newversion', 'registerconceptdoi': 'https://zenodo.org/api/deposit/depositions/14048336/actions/registerconceptdoi'}, 'record_id': 14048336, 'owner': 393191, 'files': [], 'state': 'unsubmitted', 'submitted': False}, {'created': '2024-03-20T18:48:20.471595+00:00', 'modified': '2024-03-22T00:02:00.566146+00:00', 'id': 10840694, 'conceptrecid': '10840693', 'doi': '10.5281/zenodo.10840694', 'conceptdoi': '10.5281/zenodo.10840693', 'doi_url': 'https://doi.org/10.5281/zenodo.10840694', 'metadata': {'title': 'Observing the Galactic Underworld: Code supplement to predicting photometry and astrometry from compact remnant microlensing events', 'doi': '10.5281/zenodo.10840694', 'publication_date': '2024-03-20', 'description': '<p>Code and data used/generated throughout the research for the Observing the Galactic Underworld paper.</p>\n<p>&nbsp;</p>\n<p>This project contains the following underlying code and data:</p>\n<ul>\n<li>calculate_incidence.py; code which loads in a population of objects, calculates their path on the sky, queries Gaia for objects near that path and then calculates microlensing event.&nbsp;&nbsp;</li>\n<li>plot_microlensing_results.py; collection of plotting functions used to visualise the distribution of microlensing events. Most plots in the paper are generated by this script.</li>\n<li>Plot Preparation.pynb; Jupyter notebook for exploring the data and generating plots. Any plots in the paper which are not gerneated by plot_microlensing_results.py are generated by this notebook.</li>\n<li>10000_year_lensing_result ...

# %%
headers = {"Content-Type": "application/json"}
params = {'access_token': ACCESS_TOKEN}
r = requests.post('https://zenodo.org/api/deposit/depositions',
                   params=params, json={}, headers=headers)
print(r.status_code)
# # 201
r.json()
# Out:
# 201
# {'created': '2024-11-08T05:39:11.243210+00:00',
#  'modified': '2024-11-08T05:39:11.307021+00:00',
#  'id': 14053717,
#  'conceptrecid': '14053716',
#  'metadata': {'access_right': 'open',
#   'prereserve_doi': {'doi': '10.5281/zenodo.14053717', 'recid': 14053717}},
#  'title': '',
#  'links': {'self': 'https://zenodo.org/api/deposit/depositions/14053717',
#   'html': 'https://zenodo.org/deposit/14053717',
#   'badge': 'https://zenodo.org/badge/doi/.svg',
#   'files': 'https://zenodo.org/api/deposit/depositions/14053717/files',
#   'bucket': 'https://zenodo.org/api/files/538ca778-60da-4743-9fc3-735b8fb0dd03',
#   'latest_draft': 'https://zenodo.org/api/deposit/depositions/14053717',
#   'latest_draft_html': 'https://zenodo.org/deposit/14053717',
#   'publish': 'https://zenodo.org/api/deposit/depositions/14053717/actions/publish',
#   'edit': 'https://zenodo.org/api/deposit/depositions/14053717/actions/edit',
#   'discard': 'https://zenodo.org/api/deposit/depositions/14053717/actions/discard',
#   'newversion': 'https://zenodo.org/api/deposit/depositions/14053717/actions/newversion',
#   'registerconceptdoi': 'https://zenodo.org/api/deposit/depositions/14053717/actions/registerconceptdoi'},
#  'record_id': 14053717,
#  'owner': 393191,
#  'files': [],
#  'state': 'unsubmitted',
#  'submitted': False}

# %%
bucket_url = r.json()["links"]["bucket"]
     

filename = "guw_f1e-1.csv"
path = "./data/" + filename

with open(path, "rb") as fp:
    r = requests.put(
        "%s/%s" % (bucket_url, filename),
        data=fp,
        params=params,
    )
r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.conda/envs/incidence/lib/python3.9/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/.conda/envs/incidence/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/.conda/envs/incidence/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/.conda/envs/incidence/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Input In [8], in <cell line: 13>()
#       7 with open(path, "rb") as fp:
#       8     r = requests.put(
#       9         "%s/%s" % (bucket_url, filename),
#      10         data=fp,
#      11         params=params,
#      12     )
# ---> 13 r.json()
#
# File ~/.conda/envs/incidence/lib/python3.9/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
r.status_code
# Out:
# 502

# %%
data = {
     'metadata': {
         'title': 'My first upload',
         'upload_type': 'poster',
         'description': 'This is my first upload',
         'creators': [{'name': 'Doe, John',
                       'affiliation': 'Zenodo'}]
     }
 }
r = requests.put('https://zenodo.org/api/deposit/depositions/%s' % deposition_id,
                  params={'access_token': ACCESS_TOKEN}, data=json.dumps(data),
                  headers=headers)
r.status_code
# 200
